# %%
import tweepy
consumer_key = "zb23npqaQ7Z5fGC7yLsU2vYiX"
consumer_secret = "oT6IsSgccGpEmw3g82zlisaLA2MtxR3sruVbAV96t044g6kbYB"
access_token = "1145925192008421376-SwEHyP3T3VQtjBwFTkv3uVWuNgJ7nI"
access_token_secret = "1NQLLoUMzZei41nQLJ3PsD8JrYYU2Povs02msKZho3aMe"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
query = "#CWC19"

language = "en"

# %%
results = api.search(q=query, lang=language,count=1000)

for tweet in results:
    print (tweet.user.screen_name,"Tweeted:",tweet.text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-23-dee6fa2909c1> in <module>
# ----> 1 results = api.search(q=query, lang=language,count=1000)
#       2
#       3 for tweet in results:
#       4     print (tweet.user.screen_name,"Tweeted:",tweet.text)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     230
#     231                 if is_rate_limit_error_message(error_msg):
# --> 232                     raise RateLimitError(error_msg, resp)
#     233                 else:
#     234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#
# ...

# %%
import csv

csvfile=open('tweets.csv','a')

csvwriter=csv.writer(csvfile)

for tweet in tweepy.Cursor(api.search,
                           q = "#CWC19",
                           since = "2019-06-01",
                           until = "2019-07-01",
                           lang = "en").items():

    # Write a row to the CSV file. I use encode UTF-8
    csvwriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print (tweet.created_at, tweet.text)
csvfile.close()
# Out:
# 2019-06-30 23:59:59 RT @saurabhdas1: It seems @msdhoni knows how to bat only in the 50th over!! #INDvENG #CWC19 #Terrible
# 2019-06-30 23:59:57 RT @cricketworldcup: "Welcome aboard the Pakistan fan bus!"
#
# This set of Pakistan fans have taken their support for their team to the next…
# 2019-06-30 23:59:54 RT @kumarmanish9: Even Sourav Ganguly has no explanation for singles frenzy by Dhoni and Jadhav when they need to accelerate the inning.
# T…
# 2019-06-30 23:59:46 RT @mirzaiqbal80: Surprisingly Indian batsmen could hit only one Six in their whole Inngs while Englisg batsmen hit 13 Sixes.
# #CWC19
# 2019-06-30 23:59:46 RT @Actor_Siddharth: With great subtlety, we have eliminated #Pakistan from #CWC19.
#
# #SurgicalStrike?
# 2019-06-30 23:59:45 RT @iihtishamm: This Indian fan told me that his second fav team is Pakistan &amp; he really wants India to face Pakistan in the #CWC19 final.…
# ...
